# %% [markdown]
# # 4 Gathering data

# %%
import pandas as pd 
df_red=pd.read_csv(r"C:\Users\HP\.jupyter\winequality-red.csv",sep=";")
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import pandas as pd 
df_wh=pd.read_csv(r"C:\Users\HP\.jupyter\winequality-white.csv",sep=";")
df_wh
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # 5 Assessing data

# %%
#number of samples in each dataset
#number of columns in each dataset

# %%
print(df_red.shape)
print(df_wh.shape)
# Out:
# (1599, 12)
# (4898, 12)

# %%
#features with missing values

# %%
df_red.info()
df_wh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# ...

# %%
#duplicate rows in the white wine dataset

# %%
df_red.duplicated().sum()
# Out:
# 240

# %%
df_wh.duplicated().sum()
# Out:
# 937

# %%
#number of unique values for quality in each dataset

# %%
df_red['quality'].nunique()
# Out:
# 6

# %%
df_wh['quality'].nunique()
# Out:
# 7

# %%
#mean density of the red wine dataset

# %%
df_red['density'].mean()
# Out:
# 0.9967466791744831

# %% [markdown]
# # 6 Appending and NumPy

# %%
import numpy as np
a=np.random.random(int(1e8))

# %%
import time
start=time.time()
sum(a)/len(a)
print(time.time()-start ,'seconds')
# Out:
# 17.669350385665894 seconds

# %%
import time
start=time.time()
np.mean(a)
print(time.time()-start ,'seconds')
# Out:
# 0.24173951148986816 seconds

# %% [markdown]
# # 7 Appending Data

# %%
import pandas as pd 
import numpy as np
df_red=pd.read_csv(r"C:\Users\HP\.jupyter\winequality-red.csv",sep=";")
df_wh=pd.read_csv(r"C:\Users\HP\.jupyter\winequality-white.csv",sep=";")

# %%
# create color array for red dataframe
color_red = np.repeat('red',1599)#('red',shape[0])
df_red['color']=color_red
# create color array for white dataframe
color_wh = np.repeat('white',4898)
df_wh['color']=color_wh

# %%
df_wh
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_wine=df_red.append(df_wh)
df_wine
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10624\2362774648.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_wine=df_red.append(df_wh)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# ...

# %%
df_wine.to_csv(r'C:\Users\HP\.jupyter\winequality_edited.csv',index=False)

# %%
df_wine.head(90000)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # 9 Renaming Columns

# %%
#df=df.rename(columns = {'old_name' : 'new_name'},inplace=True)
#df_red.rename()

# %% [markdown]
# # 10 Appending Data (cont.)

# %%
df_wine.shape
# Out:
# (6497, 13)

# %% [markdown]
# # 11 Exploring with Visuals

# %%
df_wine.hist(figsize=(8,8));

# %%
df_wine.plot(kind='scatter',x='quality',y='alcohol');

# %%
df_wine.plot(kind='scatter',x='quality',y='residual sugar');

# %%
df_wine.plot(kind='scatter',x='quality',y='volatile acidity');

# %%
df_wine.plot(kind='scatter',x='quality',y='pH');

# %% [markdown]
# # 12 Pandas Groupby

# %%
df_wine.mean()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10624\2506850021.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_wine.mean()
# fixed acidity             7.215307
# volatile acidity          0.339666
# citric acid               0.318633
# residual sugar            5.443235
# chlorides                 0.056034
# free sulfur dioxide      30.525319
# total sulfur dioxide    115.744574
# density                   0.994697
# pH                        3.218501
# sulphates                 0.531268
# alcohol                  10.491801
# quality                   5.818378
# dtype: float64

# %%
df_wine.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             7.853333          0.517000     0.281000        5.140000
# 4             7.288889          0.457963     0.272315        4.153704
# 5             7.326801          0.389614     0.307722        5.804116
# 6             7.177257          0.313863     0.323583        5.549753
# 7             7.128962          0.288800     0.334764        4.731696
# 8             6.835233          0.291010     0.332539        5.382902
# 9             7.420000          0.298000     0.386000        4.120000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.077033            39.216667            122.033333  0.995744
# 4         0.060056            20.636574            103.432870  0.994833
# 5         0.064666            30.237371            120.839102  0.995849
# 6         0.054157            31.165021            115.410790  0.994558
# ...

# %%
df_wine.groupby(['quality','color'],as_index=False)['pH'].mean()
# Out:
#     quality  color        pH
# 0         3    red  3.398000
# 1         3  white  3.187500
# 2         4    red  3.381509
# 3         4  white  3.182883
# 4         5    red  3.304949
# 5         5  white  3.168833
# 6         6    red  3.318072
# 7         6  white  3.188599
# 8         7    red  3.290754
# 9         7  white  3.213898
# 10        8    red  3.267222
# 11        8  white  3.218686
# 12        9  white  3.308000

# %% [markdown]
# # 13 Conclusions Using Groupby

# %%
df_wine.groupby('color',as_index=False).mean()
#Is a certain type of wine associated with higher quality?
# Out:
#    color  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0    red       8.319637          0.527821     0.270976        2.538806
# 1  white       6.854788          0.278241     0.334192        6.391415
#
#    chlorides  free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0   0.087467            15.874922             46.467792  0.996747  3.311113
# 1   0.045772            35.308085            138.360657  0.994027  3.188267
#
#    sulphates    alcohol   quality
# 0   0.658149  10.422983  5.636023
# 1   0.489847  10.514267  5.877909

# %%
df_wine.describe()
#What level of acidity receives the highest average rating?
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [2.72, 3.11, 3.21, 3.32, 4.01] # Fill in this list with five values you just found

# %%
# Labels for the four acidity level groups
bin_names = ['high', 'mod_high', 'medium', 'low'] # Name each acidity level category

# %%
df_wine["acidity_levels"]=pd.cut(df_wine['pH'],bin_edges,labels=bin_names)
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df_wine.to_csv(r'C:\Users\HP\.jupyter\winequality_edited.csv',index=False)

# %%
df_wine.groupby(['acidity_levels'],as_index=False)['quality'].mean()
# Out:
#   acidity_levels   quality
# 0           high  5.783343
# 1       mod_high  5.784540
# 2         medium  5.850832
# 3            low  5.859593

# %% [markdown]
# # 14 Pandas Query

# %%
df_wine.query("density >= 0.99")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4891            5.7              0.21         0.32             0.9      0.038
# 4892            6.5              0.23         0.38             1.3      0.032
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
#
# ...

# %% [markdown]
# # 15 Conclusions Using Query

# %%
# get the median amount of alcohol content
df_wine['alcohol'].median()
# Out:
# 10.3

# %%
# select samples with alcohol content less than the median
low_alcohol = df_wine.query("alcohol < 10.3")

# select samples with alcohol content greater than or equal to the median
high_alcohol = df_wine.query("alcohol >= 10.3")

# ensure these queries included each sample exactly once
num_samples = df_wine.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low alcohol and high alcohol groups
low_alcohol.quality.mean(),high_alcohol.quality.mean()
# Out:
# (5.475920679886686, 6.146084337349397)

# %%
#--------------------

# %%
# get the median amount of residual sugar
df_wine['residual sugar'].median()
# Out:
# 3.0

# %% [markdown]
# ### rename column

# %%
df_wine.rename(columns = {'residual sugar' : 'residual_sugar'},inplace=True)

# %%
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# select samples with residual sugar less than the median
low_sugar =df_wine.query('residual_sugar < 3.0')

# select samples with residual sugar greater than or equal to the median
high_sugar = df_wine.query('residual_sugar >= 3.0')
# ensure these queries included each sample exactly once
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count() # should be True
# Out:
# True

# %%
low_sugar.quality.mean(),high_sugar.quality.mean()
# Out:
# (5.808800743724822, 5.82782874617737)

# %% [markdown]
# # 16 Type & Quality Plot - Part 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df_wine=pd.read_csv(r'C:\Users\HP\.jupyter\winequality_edited.csv')
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
colors=('red','gray')
df_wine.groupby('color')['quality'].mean().plot(kind='bar',color=colors,title='Average Wine Quality by Color',alpha=0.7);
plt.xlabel('color',fontsize=18);
plt.ylabel('quality',fontsize=18);

# %% [markdown]
# # 17 Type & Quality Plot - Part 2

# %%
counts=df_wine.groupby(['quality','color']).count()
counts
# Out:
#                fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality color
# 3       red               10                10           10              10
#         white             20                20           20              20
# 4       red               53                53           53              53
#         white            163               163          163             163
# 5       red              681               681          681             681
#         white           1457              1457         1457            1457
# 6       red              638               638          638             638
#         white           2198              2198         2198            2198
# 7       red              199               199          199             199
#         white            880               880          880             880
# 8       red               18                18           18              18
# ...

# %%
counts=df_wine.groupby(['quality','color']).count()['pH']
counts
# Out:
# quality  color
# 3        red        10
#          white      20
# 4        red        53
#          white     163
# 5        red       681
#          white    1457
# 6        red       638
#          white    2198
# 7        red       199
#          white     880
# 8        red        18
#          white     175
# 9        white       5
# Name: pH, dtype: int64

# %%
counts=df_wine.groupby(['quality','color']).count()['pH']
colors=('red','gray')
counts.plot(kind='bar',color=colors,title='Counts by Wine Color and Quality',alpha=0.7);
plt.xlabel('color and quality',fontsize=18);
plt.ylabel('counts',fontsize=18);

# %%
totals = df_wine.groupby('color').count()['pH']
proportion=counts/totals
colors=('red','gray')
proportion.plot(kind='bar',color=colors,title='proportion by Wine Color and Quality',alpha=0.7);
plt.xlabel('color and quality',fontsize=18);
plt.ylabel('proportion',fontsize=18);

# %% [markdown]
# # 19 Plotting with Matplotlib

# %%
median=df_wine['alcohol'].median()
low=df_wine.query('alcohol < {}'.format(median))
high=df_wine.query('alcohol >= {}'.format(median))
#low,high,median
mean_quality_low=low['quality'].mean()
mean_quality_high=high['quality'].mean()

# %%
locations=[1, 2];
hights=[mean_quality_low,mean_quality_high];
labels=['Low','High'];
plt.bar(locations,hights,tick_label=labels);
plt.title('Average Quality Ratings by Alcohol Content');
plt.xlabel('Alcohol Content');
plt.ylabel('Average Quality Rating');

# %%
df_wine.rename(columns = {'residual sugar' : 'residual_sugar'},inplace=True)

# %%
median=df_wine['residual_sugar'].median()
low=df_wine.query('residual_sugar < {}'.format(median))
high=df_wine.query('residual_sugar >= {}'.format(median))
#low,high,median
mean_quality_low=low['quality'].mean()
mean_quality_high=high['quality'].mean()

# %%
location=[1,2];
hights=[mean_quality_low,mean_quality_high];
labels=['Low','High'];
plt.bar(location,hights,tick_label=labels);
plt.title('Average Quality Ratings by residual sugar Content');
plt.xlabel('residual sugar Content');
plt.ylabel('Average Quality Rating');

# %%
df_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
acidity_level_quality_means = df_wine.groupby('acidity_levels').quality.mean()
acidity_level_quality_means
# Out:
# acidity_levels
# high        5.783343
# low         5.859593
# medium      5.850832
# mod_high    5.784540
# Name: quality, dtype: float64

# %%
locations=[4,1,2,3]
heights=acidity_level_quality_means
# labels = ['Low', 'Medium', 'Moderately High', 'High']
labels=acidity_level_quality_means.index.str.replace('_',' ').str.title()
plt.bar(locations,heights,tick_label=labels);
plt.title('Average Quality Ratings by Acidity Level');
plt.xlabel('Acidity Level');
plt.ylabel('Average Quality Rating');

# %%
#Create arrays for red bar heights white bar heights

# %%
# get counts for each rating and color
color_counts = df_wine.groupby(['color', 'quality']).count()['pH']
color_counts
# Out:
# color  quality
# red    3            10
#        4            53
#        5           681
#        6           638
#        7           199
#        8            18
# white  3            20
#        4           163
#        5          1457
#        6          2198
#        7           880
#        8           175
#        9             5
# Name: pH, dtype: int64

# %%
# get total counts for each color
color_totals = df_wine.groupby('color').count()['pH']
color_totals
# Out:
# color
# red      1599
# white    4898
# Name: pH, dtype: int64

# %%
# get proportions by dividing red rating counts by total # of red samples
red_proportions = color_counts['red'] / color_totals['red']
red_proportions
# Out:
# quality
# 3    0.006254
# 4    0.033146
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 8    0.011257
# Name: pH, dtype: float64

# %%
white_proportions = color_counts['white'] / color_totals['white']
white_proportions
# Out:
# quality
# 3    0.004083
# 4    0.033279
# 5    0.297468
# 6    0.448755
# 7    0.179665
# 8    0.035729
# 9    0.001021
# Name: pH, dtype: float64

# %%
ind = np.arange(len(red_proportions))  # the x locations for the groups
width = 0.35       # the width of the bars
ind
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
# plot bars
red_bars = plt.bar(ind, red_proportions, width, color='r', alpha=.7, label='Red Wine')
white_bars = plt.bar(ind + width, white_proportions, width, color='w', alpha=.7, label='White Wine')

# title and labels
plt.ylabel('Proportion')
plt.xlabel('Quality')
plt.title('Proportion by Wine Color and Quality')
locations = ind + width / 2  # xtick locations
labels = ['3', '4', '5', '6', '7', '8', '9']  # xtick labels
plt.xticks(locations, labels)

# legend
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [73], in <cell line: 3>()
#       1 # plot bars
#       2 red_bars = plt.bar(ind, red_proportions, width, color='r', alpha=.7, label='Red Wine')
# ----> 3 white_bars = plt.bar(ind + width, white_proportions, width, color='w', alpha=.7, label='White Wine')
#       5 # title and labels
#       6 plt.ylabel('Proportion')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2399, in bar(x, height, width, bottom, align, data, **kwargs)
#    2395 @_copy_docstring_and_deprecators(Axes.bar)
#    2396 def bar(
#    2397         x, height, width=0.8, bottom=None, *, align='center',
#    2398         data=None, **kwargs):
# -> 2399     return gca().bar(
#    2400         x, height, width=width, bottom=bottom, align=align,
#    2401         **({"data": data} if data is not None else {}), **kwargs)
#
# ...
