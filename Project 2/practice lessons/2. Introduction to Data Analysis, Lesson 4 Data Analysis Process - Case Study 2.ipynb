# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # 6 Assessing Data

# %%
c2008=pd.read_csv(r"C:\Users\HP\.jupyter\all_alpha_08.csv")
c2018=pd.read_csv(r"C:\Users\HP\.jupyter\all_alpha_18.csv")

# %%
c2018.info(),c2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 1611 non-null   object
#  1   Displ                 1609 non-null   float64
#  2   Cyl                   1609 non-null   float64
#  3   Trans                 1611 non-null   object
#  4   Drive                 1611 non-null   object
#  5   Fuel                  1611 non-null   object
#  6   Cert Region           1611 non-null   object
#  7   Stnd                  1611 non-null   object
#  8   Stnd Description      1611 non-null   object
#  9   Underhood ID          1611 non-null   object
#  10  Veh Class             1611 non-null   object
#  11  Air Pollution Score   1611 non-null   int64
#  12  City MPG              1611 non-null   object
#  13  Hwy MPG               1611 non-null   object
#  14  Cmb MPG               1611 non-null   object
# ...

# %%
c2018.dtypes,c2008.dtypes
# Out:
# (Model                    object
#  Displ                   float64
#  Cyl                     float64
#  Trans                    object
#  Drive                    object
#  Fuel                     object
#  Cert Region              object
#  Stnd                     object
#  Stnd Description         object
#  Underhood ID             object
#  Veh Class                object
#  Air Pollution Score       int64
#  City MPG                 object
#  Hwy MPG                  object
#  Cmb MPG                  object
#  Greenhouse Gas Score      int64
#  SmartWay                 object
#  Comb CO2                 object
#  dtype: object,
#  Model                    object
#  Displ                   float64
#  Cyl                      object
#  Trans                    object
#  Drive                    object
#  Fuel                     object
#  Sales Area               object
#  Stnd                     object
#  Underhood ID             object
#  Veh Class                object
# ...

# %%
c2018.duplicated().sum(),c2008.duplicated().sum()
# Out:
# (0, 25)

# %%
c2018.isnull().sum(),c2008.isnull().sum()
# Out:
# (Model                   0
#  Displ                   2
#  Cyl                     2
#  Trans                   0
#  Drive                   0
#  Fuel                    0
#  Cert Region             0
#  Stnd                    0
#  Stnd Description        0
#  Underhood ID            0
#  Veh Class               0
#  Air Pollution Score     0
#  City MPG                0
#  Hwy MPG                 0
#  Cmb MPG                 0
#  Greenhouse Gas Score    0
#  SmartWay                0
#  Comb CO2                0
#  dtype: int64,
#  Model                     0
#  Displ                     0
#  Cyl                     199
#  Trans                   199
#  Drive                    93
#  Fuel                      0
#  Sales Area                0
#  Stnd                      0
#  Underhood ID              0
#  Veh Class                 0
#  Air Pollution Score       0
#  FE Calc Appr            199
#  City MPG                199
#  Hwy MPG                 199
# ...

# %%
c2018.SmartWay.nunique(),c2008.SmartWay.nunique()
# Out:
# (3, 2)

# %%
c2008['Sales Area'].nunique()
# Out:
# 3

# %%
c2018['Cert Region'].nunique()
# Out:
# 2

# %%
c2008['Trans'].nunique()
# Out:
# 14

# %%
c2008.Cyl.nunique(),c2018.Cyl.nunique()
# Out:
# (8, 7)

# %%
c2018.Fuel.unique(),c2008.Fuel.unique()
# Out:
# array(['Gasoline', 'Gasoline/Electricity', 'Diesel', 'Ethanol/Gas',
#        'Electricity'], dtype=object)

# %% [markdown]
# # 6 Cleaning Column Labels

# %%
df_08=pd.read_csv(r"C:\Users\HP\.jupyter\all_alpha_08.csv")
df_18=pd.read_csv(r"C:\Users\HP\.jupyter\all_alpha_18.csv")

# %%
df_08.head(1)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID Veh Class Air Pollution Score FE Calc Appr City MPG Hwy MPG  \
# 0  8HNXT03.7PKR       SUV                   7          Drv       15      20
#
#   Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# 0      17        22.0527                    4       no

# %%
df_18.head(1)
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region    Stnd  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  T3B125
#
#          Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0  Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
#
#   City MPG Hwy MPG Cmb MPG  Greenhouse Gas Score SmartWay Comb CO2
# 0       20      28      23                     5       No      386

# %%
#df_08.drop(['Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'],axis=1 ,inplace=True) #1 mean columns
df_08.head(0)
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, cert_region, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_18.drop(['stnd_description', 'comb_co2'],axis=1 ,inplace=True) #1 mean columns
df_18.head(0)
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, cert_region, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08.rename(columns={'Sales Area':'Cert Region'},inplace=True)
df_08.head(1)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Cert Region Veh Class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA       SUV
#
#   Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score SmartWay
# 0                   7       15      20      17                    4       no

# %%
df_08.rename(columns=lambda x:x.strip().lower().replace(" ",'_'),inplace=True)
df_08.head(1)
# Out:
#        model  displ      cyl    trans drive      fuel cert_region veh_class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA       SUV
#
#   air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# 0                   7       15      20      17                    4       no

# %%
df_18.rename(columns=lambda x:x.strip().lower().replace(" ",'_'),inplace=True)
df_18.head(1)
# Out:
#        model  displ  cyl       trans drive      fuel cert_region  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA
#
#          stnd_description  veh_class  air_pollution_score city_mpg hwy_mpg  \
# 0  Federal Tier 3 Bin 125  small SUV                    3       20      28
#
#   cmb_mpg  greenhouse_gas_score smartway comb_co2
# 0      23                     5       No      386

# %%
df_18.columns == df_08.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
(df_08.columns == df_18.columns).all()
# Out:
# True

# %%
df_08.to_csv(r"C:\Users\HP\.jupyter\dtat_08_v1.csv")
df_18.to_csv(r"C:\Users\HP\.jupyter\dtat_18_v1.csv")

# %% [markdown]
# # 7 Filter, Drop Nulls, Dedupe

# %%
df_08 = pd.read_csv(r"C:\Users\HP\.jupyter\data_08_v1.csv")
df_18 =pd.read_csv(r"C:\Users\HP\.jupyter\data_18_v1.csv")

# %%
df_08.shape
# Out:
# (2404, 14)

# %%
df_18.shape
# Out:
# (1611, 14)

# %%
df_08
# Out:
#             model  displ      cyl    trans drive      fuel cert_region  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# ...           ...    ...      ...      ...   ...       ...         ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          FA
#
#         veh_class air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_18
# Out:
#             model  displ  cyl       trans drive                  fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      cert_region     veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_08.query("cert_region == 'CA'",inplace=True)

# %%
df_18.query("cert_region == 'CA'",inplace=True)

# %%
df_08['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
df_18['cert_region'].unique()
# Out:
# array(['CA'], dtype=object)

# %%
#df_08.drop('cert_region',axis=1,inplace=True)
df_08
# Out:
#             model  displ      cyl    trans drive      fuel      veh_class  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline            SUV
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline            SUV
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline    midsize car
# 6        ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline    midsize car
# 7        ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline    midsize car
# ...           ...    ...      ...      ...   ...       ...            ...
# 2394    VOLVO V70    3.2  (6 cyl)  Auto-S6   2WD  Gasoline  station wagon
# 2396  VOLVO XC 70    3.2  (6 cyl)  Auto-S6   4WD  Gasoline            SUV
# 2398  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline            SUV
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline            SUV
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline            SUV
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# ...

# %%
#df_18.drop('cert_region',axis=1,inplace=True)
df_18
# Out:
#             model  displ  cyl       trans drive                  fuel  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD              Gasoline
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD              Gasoline
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#          veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# ...

# %%
df_08.shape,df_18.shape
# Out:
# ((1084, 13), (798, 13))

# %%
df_08.isnull().sum(),df_18.isnull().sum()
# Out:
# (model                    0
#  displ                    0
#  cyl                     75
#  trans                   75
#  drive                   37
#  fuel                     0
#  veh_class                0
#  air_pollution_score      0
#  city_mpg                75
#  hwy_mpg                 75
#  cmb_mpg                 75
#  greenhouse_gas_score    75
#  smartway                 0
#  dtype: int64,
#  model                   0
#  displ                   1
#  cyl                     1
#  trans                   0
#  drive                   0
#  fuel                    0
#  veh_class               0
#  air_pollution_score     0
#  city_mpg                0
#  hwy_mpg                 0
#  cmb_mpg                 0
#  greenhouse_gas_score    0
#  smartway                0
#  dtype: int64)

# %%
#drop na
df_08.dropna(inplace=True)
df_18.dropna(inplace=True)

# %%
df_08.isnull().sum(),df_18.isnull().sum()
# Out:
# (model                   0
#  displ                   0
#  cyl                     0
#  trans                   0
#  drive                   0
#  fuel                    0
#  veh_class               0
#  air_pollution_score     0
#  city_mpg                0
#  hwy_mpg                 0
#  cmb_mpg                 0
#  greenhouse_gas_score    0
#  smartway                0
#  dtype: int64,
#  model                   0
#  displ                   0
#  cyl                     0
#  trans                   0
#  drive                   0
#  fuel                    0
#  veh_class               0
#  air_pollution_score     0
#  city_mpg                0
#  hwy_mpg                 0
#  cmb_mpg                 0
#  greenhouse_gas_score    0
#  smartway                0
#  dtype: int64)

# %%
df_08.isnull().sum().any(),df_18.isnull().sum().any()
# Out:
# (False, False)

# %%
#drop na
df_08.drop_duplicates(inplace=True)
df_18.drop_duplicates(inplace=True)

# %%
df_08.duplicated().sum(),df_18.duplicated().sum()
# Out:
# (0, 0)

# %%
df_08.to_csv(r"C:\Users\HP\.jupyter\dtat_08_v2.csv")
df_18.to_csv(r"C:\Users\HP\.jupyter\dtat_18_v2.csv")

# %%
df_08.shape,df_18.shape
# Out:
# ((986, 13), (794, 13))

# %% [markdown]
# # 9 Fixing Data Types Pt 1

# %%
df_08=pd.read_csv(r"C:\Users\HP\.jupyter\dtat_08_v2.csv")
df_18=pd.read_csv(r"C:\Users\HP\.jupyter\dtat_18_v2.csv")

# %%
df_08['cyl'].value_counts()
# Out:
# (6 cyl)     409
# (4 cyl)     283
# (8 cyl)     199
# (5 cyl)      48
# (12 cyl)     30
# (10 cyl)     14
# (2 cyl)       2
# (16 cyl)      1
# Name: cyl, dtype: int64

# %%
df_18['cyl'].value_counts()
# Out:
# 4.0     365
# 6.0     246
# 8.0     153
# 3.0      18
# 12.0      9
# 5.0       2
# 16.0      1
# Name: cyl, dtype: int64

# %%
df_08['cyl']=df_08['cyl'].str.extract('(\d+)').astype(int)

# %%
df_08.dtypes
# Out:
# Unnamed: 0                int64
# model                    object
# displ                   float64
# cyl                       int32
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score      object
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score     object
# smartway                 object
# dtype: object

# %%
df_18['cyl']=df_18['cyl'].astype(int)

# %%
df_18.dtypes
# Out:
# Unnamed: 0                int64
# model                    object
# displ                   float64
# cyl                       int32
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score       int64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score      int64
# smartway                 object
# dtype: object

# %%
df_08.to_csv(r"C:\Users\HP\.jupyter\dtat_08_v3.csv",index=False)
df_18.to_csv(r"C:\Users\HP\.jupyter\dtat_18_v3.csv",index=False)

# %% [markdown]
# # 10 Fixing Data Types Pt 2

# %%
df_08=pd.read_csv(r"C:\Users\HP\.jupyter\dtat_08_v3.csv")
df_18=pd.read_csv(r"C:\Users\HP\.jupyter\dtat_18_v3.csv")

# %%
#df_08.drop(columns='Unnamed: 0',inplace=True)
df_08
# Out:
#            model  displ  cyl    trans drive      fuel      veh_class  \
# 0      ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline            SUV
# 1      ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline            SUV
# 2       ACURA RL    3.5    6  Auto-S5   4WD  Gasoline    midsize car
# 3       ACURA TL    3.2    6  Auto-S5   2WD  Gasoline    midsize car
# 4       ACURA TL    3.5    6  Auto-S5   2WD  Gasoline    midsize car
# ..           ...    ...  ...      ...   ...       ...            ...
# 981    VOLVO V70    3.2    6  Auto-S6   2WD  Gasoline  station wagon
# 982  VOLVO XC 70    3.2    6  Auto-S6   4WD  Gasoline            SUV
# 983  VOLVO XC 90    3.2    6  Auto-S6   2WD  Gasoline            SUV
# 984  VOLVO XC 90    3.2    6  Auto-S6   4WD  Gasoline            SUV
# 985  VOLVO XC 90    4.4    8  Auto-S6   4WD  Gasoline            SUV
#
#     air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score smartway
# ...

# %%
#df_18.drop("Unnamed: 0",axis=1,inplace=True)
df_18
# Out:
#            model  displ  cyl       trans drive                  fuel  \
# 0      ACURA RDX    3.5    6  SemiAuto-6   2WD              Gasoline
# 1      ACURA RDX    3.5    6  SemiAuto-6   4WD              Gasoline
# 2      ACURA TLX    2.4    4       AMS-8   2WD              Gasoline
# 3      ACURA TLX    3.5    6  SemiAuto-9   2WD              Gasoline
# 4      ACURA TLX    3.5    6  SemiAuto-9   4WD              Gasoline
# ..           ...    ...  ...         ...   ...                   ...
# 789  VOLVO XC 60    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
# 790  VOLVO XC 90    2.0    4  SemiAuto-8   2WD              Gasoline
# 791  VOLVO XC 90    2.0    4  SemiAuto-8   4WD              Gasoline
# 792  VOLVO XC 90    2.0    4  SemiAuto-8   4WD              Gasoline
# 793  VOLVO XC 90    2.0    4  SemiAuto-8   4WD  Gasoline/Electricity
#
#         veh_class  air_pollution_score city_mpg hwy_mpg cmb_mpg  \
# 0       small SUV                    3       20      28      23
# ...

# %%
#--------------------------------------------------------------------------

# %%
df_08[df_08.air_pollution_score == '6/4']
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
#df_08.air_pollution_score.astype(int)

# %%
hb_08=df_08[df_08['fuel'].str.contains('/')]
hb_08
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
hb_18=df_18[df_18['fuel'].str.contains('/')]
hb_18
# Out:
#                                  model  displ  cyl       trans drive  \
# 52                            BMW 330e    2.0    4  SemiAuto-8   2WD
# 78                            BMW 530e    2.0    4  SemiAuto-8   2WD
# 79                            BMW 530e    2.0    4  SemiAuto-8   4WD
# 92                            BMW 740e    2.0    4  SemiAuto-8   4WD
# 189                   CHEVROLET Impala    3.6    6  SemiAuto-6   2WD
# 195             CHEVROLET Silverado 15    4.3    6      Auto-6   2WD
# 196             CHEVROLET Silverado 15    4.3    6      Auto-6   4WD
# 197             CHEVROLET Silverado 15    5.3    8      Auto-6   2WD
# 212            CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 214            CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 216               CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 218               CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# 225                     CHEVROLET Volt    1.5    4         CVT   2WD
# ...

# %%
df1=hb_08.copy()
df2=hb_08.copy()

# %%
df1
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df2
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# columns to split by "/"
split_columns=['fuel','city_mpg','hwy_mpg','cmb_mpg']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c]=df1[c].apply(lambda x: x.split('/')[0])
    df2[c]=df2[c].apply(lambda x: x.split('/')[1])

# %%
df1
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df2
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
# combine dataframes to add to the original dataframe
new_rows=df1.append(df2)
new_rows
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22612\2232756448.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows=df1.append(df2)
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08.drop(hb_08.index,inplace=True)

# %%
df_08=df_08.append(new_rows,ignore_index=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22612\116594732.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_08=df_08.append(new_rows,ignore_index=True)

# %%
df_08[df_08['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_08.shape
# Out:
# (1025, 13)

# %%
#---------------------------------------------------------

# %%
df1=hb_18.copy()
df2=hb_18.copy()

# %%
df_18[df_18['fuel'].str.contains('/')]
# Out:
#                                  model  displ  cyl       trans drive  \
# 52                            BMW 330e    2.0    4  SemiAuto-8   2WD
# 78                            BMW 530e    2.0    4  SemiAuto-8   2WD
# 79                            BMW 530e    2.0    4  SemiAuto-8   4WD
# 92                            BMW 740e    2.0    4  SemiAuto-8   4WD
# 189                   CHEVROLET Impala    3.6    6  SemiAuto-6   2WD
# 195             CHEVROLET Silverado 15    4.3    6      Auto-6   2WD
# 196             CHEVROLET Silverado 15    4.3    6      Auto-6   4WD
# 197             CHEVROLET Silverado 15    5.3    8      Auto-6   2WD
# 212            CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 214            CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 216               CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 218               CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# 225                     CHEVROLET Volt    1.5    4         CVT   2WD
# ...

# %%
# columns to split by "/"
split_columns=['fuel','city_mpg','hwy_mpg','cmb_mpg']

# apply split function to each column of each dataframe copy
for c in split_columns:
    df1[c]=df1[c].apply(lambda x: x.split('/')[0])
    df2[c]=df2[c].apply(lambda x: x.split('/')[1])

# %%
new_rows=df1.append(df2)
new_rows
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22612\691991278.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_rows=df1.append(df2)
#                   model  displ  cyl       trans drive         fuel  \
# 52             BMW 330e    2.0    4  SemiAuto-8   2WD     Gasoline
# 78             BMW 530e    2.0    4  SemiAuto-8   2WD     Gasoline
# 79             BMW 530e    2.0    4  SemiAuto-8   4WD     Gasoline
# 92             BMW 740e    2.0    4  SemiAuto-8   4WD     Gasoline
# 189    CHEVROLET Impala    3.6    6  SemiAuto-6   2WD      Ethanol
# ..                  ...    ...  ...         ...   ...          ...
# 741  TOYOTA Sequoia FFV    5.7    8  SemiAuto-6   4WD          Gas
# 746   TOYOTA Tundra FFV    5.7    8  SemiAuto-6   4WD          Gas
# 776           VOLVO S90    2.0    4  SemiAuto-8   4WD  Electricity
# 788         VOLVO XC 60    2.0    4  SemiAuto-8   4WD  Electricity
# ...

# %%
df_18.drop(hb_18.index,inplace=True)

# %%
df_18=df_18.append(new_rows,ignore_index=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22612\3061612467.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_18=df_18.append(new_rows,ignore_index=True)

# %%
df_18[df_18['fuel'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_18.shape
# Out:
# (909, 13)

# %%
df_08.air_pollution_score=df_08.air_pollution_score.astype(float) #convert data type to float

# %%
df_18.air_pollution_score=df_18.air_pollution_score.astype(float)

# %%
df_08.dtypes
# Out:
# model                    object
# displ                   float64
# cyl                       int64
# trans                    object
# drive                    object
# fuel                     object
# veh_class                object
# air_pollution_score     float64
# city_mpg                 object
# hwy_mpg                  object
# cmb_mpg                  object
# greenhouse_gas_score     object
# smartway                 object
# dtype: object

# %%
df_08.to_csv(r"C:\Users\HP\.jupyter\dtat_08_v4.csv", index=False)
df_18.to_csv(r"C:\Users\HP\.jupyter\dtat_18_v4.csv", index=False)

# %% [markdown]
# # 11 Fixing Data Types Pt 3

# %%
df_08=pd.read_csv(r"C:\Users\HP\.jupyter\dtat_08_v4.csv")
df_18=pd.read_csv(r"C:\Users\HP\.jupyter\dtat_18_v4.csv")

# %%
mpg_columns=['city_mpg', 'hwy_mpg', 'cmb_mpg']
for m in mpg_columns:
    df_18[m] = df_18[m].astype(float)
    df_08[m] = df_08[m].astype(float)

# %%
df_08['greenhouse_gas_score'] =df_08['greenhouse_gas_score'].astype(int)
df_18['greenhouse_gas_score'] =df_18['greenhouse_gas_score'].astype(int)

# %%
df_08.dtypes, df_18.dtypes
# Out:
# (model                    object
#  displ                   float64
#  cyl                       int64
#  trans                    object
#  drive                    object
#  fuel                     object
#  veh_class                object
#  air_pollution_score     float64
#  city_mpg                float64
#  hwy_mpg                 float64
#  cmb_mpg                 float64
#  greenhouse_gas_score      int32
#  smartway                 object
#  dtype: object,
#  model                    object
#  displ                   float64
#  cyl                       int64
#  trans                    object
#  drive                    object
#  fuel                     object
#  veh_class                object
#  air_pollution_score     float64
#  city_mpg                float64
#  hwy_mpg                 float64
#  cmb_mpg                 float64
#  greenhouse_gas_score      int32
#  smartway                 object
#  dtype: object)

# %%
df_08.to_csv(r"C:\Users\HP\.jupyter\clean_08.csv", index=False)
df_18.to_csv(r"C:\Users\HP\.jupyter\clean_18.csv", index=False)

# %%
df_08
# Out:
#                    model  displ  cyl       trans drive         fuel  \
# 0              ACURA MDX    3.7    6     Auto-S5   4WD     Gasoline
# 1              ACURA RDX    2.3    4     Auto-S5   4WD     Gasoline
# 2               ACURA RL    3.5    6     Auto-S5   4WD     Gasoline
# 3               ACURA TL    3.2    6     Auto-S5   2WD     Gasoline
# 4               ACURA TL    3.5    6     Auto-S5   2WD     Gasoline
# ...                  ...    ...  ...         ...   ...          ...
# 1020  TOYOTA Sequoia FFV    5.7    8  SemiAuto-6   4WD          Gas
# 1021   TOYOTA Tundra FFV    5.7    8  SemiAuto-6   4WD          Gas
# 1022           VOLVO S90    2.0    4  SemiAuto-8   4WD  Electricity
# 1023         VOLVO XC 60    2.0    4  SemiAuto-8   4WD  Electricity
# 1024         VOLVO XC 90    2.0    4  SemiAuto-8   4WD  Electricity
#
#          veh_class  air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  \
# 0              SUV                  7.0      15.0     20.0     17.0
# ...

# %%
df_08.duplicated().sum()
# Out:
# 0

# %%
df_18.duplicated().sum()
# Out:
# 76

# %% [markdown]
# # 12 Exploring with Visuals

# %%
df_08=pd.read_csv(r"C:\Users\HP\.jupyter\clean_08.csv")
df_18=pd.read_csv(r"C:\Users\HP\.jupyter\clean_18.csv")

# %%
df_08.greenhouse_gas_score.hist();

# %%
df_18.greenhouse_gas_score.hist()
# Out:
# <AxesSubplot:>

# %%
df_08.hist(figsize=(9,9));

# %%
df_18.hist(figsize=(9,9));

# %%
df_08.plot(x='displ',y='cmb_mpg',kind='scatter');

# %%
df_18.plot(x='displ',y='cmb_mpg',kind='scatter');

# %%
# 13 Conclusions & Visuals

# %%
df_08=pd.read_csv(r"C:\Users\HP\.jupyter\clean_08.csv")
df_18=pd.read_csv(r"C:\Users\HP\.jupyter\clean_18.csv")

# %%
df_08.head()
# Out:
#        model  displ  cyl    trans drive      fuel    veh_class  \
# 0  ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          SUV
# 1  ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          SUV
# 2   ACURA RL    3.5    6  Auto-S5   4WD  Gasoline  midsize car
# 3   ACURA TL    3.2    6  Auto-S5   2WD  Gasoline  midsize car
# 4   ACURA TL    3.5    6  Auto-S5   2WD  Gasoline  midsize car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  7.0      15.0     20.0     17.0                     4
# 1                  7.0      17.0     22.0     19.0                     5
# 2                  7.0      16.0     24.0     19.0                     5
# 3                  7.0      18.0     26.0     21.0                     6
# 4                  7.0      17.0     26.0     20.0                     6
#
#   smartway
# 0       no
# 1       no
# 2       no
# 3      yes
# 4      yes

# %%
df_18.head()
# Out:
#        model  displ  cyl       trans drive      fuel  veh_class  \
# 0  ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline  small SUV
# 1  ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline  small SUV
# 2  ACURA TLX    2.4    4       AMS-8   2WD  Gasoline  small car
# 3  ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline  small car
# 4  ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline  small car
#
#    air_pollution_score  city_mpg  hwy_mpg  cmb_mpg  greenhouse_gas_score  \
# 0                  3.0      20.0     28.0     23.0                     5
# 1                  3.0      19.0     27.0     22.0                     4
# 2                  3.0      23.0     33.0     27.0                     6
# 3                  3.0      20.0     32.0     24.0                     5
# 4                  3.0      21.0     30.0     24.0                     5
#
#   smartway
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No

# %%
df_08.fuel.value_counts()
# Out:
# Gasoline    984
# CNG           1
# ethanol       1
# gas           1
# Name: fuel, dtype: int64

# %%
df_18.fuel.value_counts()
#df_08.plot(x=a,y='fuel',kind='scatter');
# Out:
# Gasoline       749
# Ethanol         26
# Gas             26
# Diesel          19
# Electricity     12
# Name: fuel, dtype: int64

# %%
alt_08=df_08.query('fuel in ["ethanol","CNG"]').model.nunique()
alt_08
# Out:
# 2

# %%
alt_18=df_18.query('fuel in ["Ethanol","Electricity"]').model.nunique()
alt_18
# Out:
# 26

# %%
plt.bar(['2008','2018'],[alt_08,alt_18])
plt.title("Number of Unique Models Using Alternative Fuels")
plt.xlabel("Year")
plt.ylabel("Number of Unique Models");

# %%
#Since 2008, the number of unique models using alternative sources of fuel increased by 24. We can also look at proportions.

# %%
# total unique models each year
total_08 = df_08.model.nunique()
total_18 = df_18.model.nunique()
total_08, total_18
# Out:
# (377, 357)

# %%
prop_08 = alt_08/total_08
prop_18 = alt_18/total_18
prop_08, prop_18
# Out:
# (0.005305039787798408, 0.07282913165266107)

# %%
plt.bar(["2008", "2018"], [prop_08, prop_18])
plt.title("Proportion of Unique Models Using Alternative Fuels")
plt.xlabel("Year")
plt.ylabel("Proportion of Unique Models");

# %%
#____________________________________________________________________

# %%
veh_08=df_08.groupby('veh_class').cmb_mpg.mean()
veh_08
# Out:
# veh_class
# SUV              18.471429
# large car        18.509091
# midsize car      21.601449
# minivan          19.117647
# pickup           16.277108
# small car        21.105105
# station wagon    22.366667
# van              14.952381
# Name: cmb_mpg, dtype: float64

# %%
veh_18=df_18.groupby('veh_class').cmb_mpg.mean()
veh_18
# Out:
# veh_class
# large car          23.409091
# midsize car        27.884058
# minivan            20.800000
# pickup             18.589744
# small SUV          24.074074
# small car          25.421053
# special purpose    18.500000
# standard SUV       18.197674
# station wagon      27.529412
# Name: cmb_mpg, dtype: float64

# %%
inc=veh_18-veh_08
inc
# Out:
# veh_class
# SUV                     NaN
# large car          4.900000
# midsize car        6.282609
# minivan            1.682353
# pickup             2.312635
# small SUV               NaN
# small car          4.315948
# special purpose         NaN
# standard SUV            NaN
# station wagon      5.162745
# van                     NaN
# Name: cmb_mpg, dtype: float64

# %%
inc.dropna(inplace=True)
plt.subplots(figsize=(8,4))
plt.bar(inc.index,inc)
plt.title('Improvements in Fuel Economy from 2008 to 2018 by Vehicle Class')
plt.xlabel('Vehicle Class')
plt.ylabel('Increase in Average Combined MPG');

# %%
#_________________________________________________________

# %%
# smartway labels for 2008
df_08.smartway.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
# get all smartway vehicles in 2008
smart_08 = df_08.query('smartway == "yes"')

# %%
# explore smartway vehicles in 2008
smart_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  380.000000  380.000000           380.000000  380.000000  380.000000
# mean     2.602895    4.826316             7.365789   20.984211   28.413158
# std      0.623436    1.002025             1.148195    3.442672    3.075194
# min      1.300000    4.000000             6.000000   17.000000   22.000000
# 25%      2.275000    4.000000             7.000000   19.000000   26.000000
# 50%      2.400000    4.000000             7.000000   20.000000   28.000000
# 75%      3.000000    6.000000             7.000000   22.000000   30.000000
# max      5.000000    8.000000             9.500000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  380.000000            380.000000
# mean    23.736842              6.868421
# std      3.060379              0.827338
# min     20.000000              6.000000
# 25%     22.000000              6.000000
# 50%     23.000000              7.000000
# ...

# %%
# smartway labels for 2018
df_18.smartway.unique()
# Out:
# array(['No', 'Yes', 'Elite'], dtype=object)

# %%
# get all smartway vehicles in 2018
smart_18 = df_18.query('smartway in ["Yes", "Elite"]')

# %%
smart_18.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  108.000000  108.000000           108.000000  108.000000  108.000000
# mean     1.787963    3.935185             5.212963   34.907407   41.472222
# std      0.408031    0.416329             1.798498   16.431982   13.095236
# min      1.200000    3.000000             3.000000   25.000000   27.000000
# 25%      1.500000    4.000000             3.000000   28.000000   36.000000
# 50%      1.700000    4.000000             5.500000   28.500000   37.000000
# 75%      2.000000    4.000000             7.000000   31.250000   40.250000
# max      3.500000    6.000000             7.000000  113.000000   99.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  108.000000            108.000000
# mean    37.361111              7.925926
# std     14.848429              1.197378
# min     26.000000              7.000000
# 25%     31.000000              7.000000
# 50%     32.000000              7.000000
# ...

# %%
#------------------------------------------------------

# %%
top_08=df_08.query('cmb_mpg > cmb_mpg.mean()')
top_08.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  519.000000  519.000000           519.000000  519.000000  519.000000
# mean     2.667823    4.890173             6.998073   20.317919   27.603083
# std      0.665551    1.034856             1.159565    3.198257    3.051120
# min      1.300000    4.000000             4.000000   17.000000   20.000000
# 25%      2.300000    4.000000             6.000000   18.000000   25.000000
# 50%      2.500000    4.000000             7.000000   20.000000   27.000000
# 75%      3.000000    6.000000             7.000000   21.000000   29.000000
# max      6.000000    8.000000             9.500000   48.000000   45.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  519.000000            519.000000
# mean    22.992293              6.639692
# std      2.926371              0.804935
# min     20.000000              6.000000
# 25%     21.000000              6.000000
# 50%     22.000000              6.000000
# ...

# %%
top_18=df_18.query('cmb_mpg > cmb_mpg.mean()')
top_18.describe()
# Out:
#             displ         cyl  air_pollution_score    city_mpg     hwy_mpg  \
# count  328.000000  328.000000           328.000000  328.000000  328.000000
# mean     1.964329    4.021341             4.856707   27.472561   35.304878
# std      0.398593    0.465477             1.860802   11.033692    9.024857
# min      1.200000    3.000000             1.000000   21.000000   27.000000
# 25%      1.600000    4.000000             3.000000   23.000000   31.000000
# 50%      2.000000    4.000000             5.000000   25.000000   33.000000
# 75%      2.000000    4.000000             7.000000   28.000000   36.000000
# max      3.500000    6.000000             7.000000  113.000000   99.000000
#
#           cmb_mpg  greenhouse_gas_score
# count  328.000000            328.000000
# mean    30.411585              6.329268
# std     10.081539              1.410358
# min     25.000000              4.000000
# 25%     26.000000              5.000000
# 50%     28.000000              6.000000
# ...

# %% [markdown]
# # 15 Merging Datasets

# %%
df_08=pd.read_csv(r"C:\Users\HP\.jupyter\clean_08.csv")
df_18=pd.read_csv(r"C:\Users\HP\.jupyter\clean_18.csv")

# %%
df_08.rename(columns=lambda x:x[:10] + '_2008',inplace=True)
df_08
# Out:
#              model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0             ACURA MDX         3.7         6    Auto-S5        4WD  Gasoline
# 1             ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2              ACURA RL         3.5         6    Auto-S5        4WD  Gasoline
# 3              ACURA TL         3.2         6    Auto-S5        2WD  Gasoline
# 4              ACURA TL         3.5         6    Auto-S5        2WD  Gasoline
# ..                  ...         ...       ...        ...        ...       ...
# 982         VOLVO XC 90         3.2         6    Auto-S6        2WD  Gasoline
# 983         VOLVO XC 90         3.2         6    Auto-S6        4WD  Gasoline
# 984         VOLVO XC 90         4.4         8    Auto-S6        4WD  Gasoline
# 985  MERCEDES-BENZ C300         3.0         6    Auto-L7        2WD   ethanol
# 986  MERCEDES-BENZ C300         3.0         6    Auto-L7        2WD       gas
#
# ...

# %%
df_combined=df_08.merge(df_18,how='inner',left_on='model_2008',right_on='model')
df_combined
# Out:
#              model_2008  displ_2008  cyl_2008 trans_2008 drive_2008 fuel_2008  \
# 0             ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 1             ACURA RDX         2.3         4    Auto-S5        4WD  Gasoline
# 2               AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 3               AUDI A3         2.0         4      Man-6        2WD  Gasoline
# 4               AUDI A3         2.0         4    Auto-S6        2WD  Gasoline
# ..                  ...         ...       ...        ...        ...       ...
# 917  MERCEDES-BENZ C300         3.0         6    Auto-L7        2WD   ethanol
# 918  MERCEDES-BENZ C300         3.0         6    Auto-L7        2WD   ethanol
# 919  MERCEDES-BENZ C300         3.0         6    Auto-L7        2WD       gas
# 920  MERCEDES-BENZ C300         3.0         6    Auto-L7        2WD       gas
# 921  MERCEDES-BENZ C300         3.0         6    Auto-L7        2WD       gas
#
# ...

# %%
df_combined.to_csv(r"C:\Users\HP\.jupyter\combined_dataset.csv", index=False)

# %%
model_mpg=df_combined.groupby('model').mean()[['cmb_mpg_2008','cmb_mpg']]
model_mpg
#mean for each cell
# Out:
#                    cmb_mpg_2008    cmb_mpg
# model
# ACURA RDX             19.000000  22.500000
# AUDI A3               23.333333  28.000000
# AUDI A4               21.000000  27.000000
# AUDI A6               19.666667  25.666667
# AUDI A8 L             16.500000  22.000000
# ...                         ...        ...
# TOYOTA Yaris          31.500000  32.500000
# VOLKSWAGEN Jetta      24.166667  30.000000
# VOLKSWAGEN Passat     21.250000  29.000000
# VOLVO S60             21.333333  27.000000
# VOLVO XC 90           15.666667  32.200000
#
# [72 rows x 2 columns]

# %%
df_combined.model.nunique()
# Out:
# 72

# %%
model_mpg['mpg_change']=model_mpg.cmb_mpg-model_mpg.cmb_mpg_2008;
model_mpg['mpg_change'].max()
# Out:
# 16.53333333333334

# %%
model_mpg.query('mpg_change == 16.53333333333334')
# Out:
#              cmb_mpg_2008  cmb_mpg  mpg_change
# model
# VOLVO XC 90     15.666667     32.2   16.533333

# %%
model_mpg['mpg_change'].idxmax()
# Out:
# 'VOLVO XC 90'
